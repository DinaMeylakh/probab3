# %%
import sys
sys.path.append("../../../../")

from probab3.commands.pre_calculation.detectors_sensitivity.detectors_sensitivity import get_detector_sensitivity

# %%
# Cosmic Explorer
strain_freq_file_path = "C:\\Users\\dinam\\OneDrive\\Documents\\huji\\research\\detectors_noise\\ce_strain\\ce_strain\\cosmic_explorer_strain.txt"

get_detector_sensitivity("Cosmic Explorer", strain_freq_file_path)
# Out:
# {'Cosmic Explorer': {'freq_range': [10.624226762494413, 1899.1076530953678],
#   'min_strain': 2.138284935904749e-25,
#   'strain_threshold': 6.414854807714247e-25}}

# %%
# LIGO (O3)
strain_freq_file_path = "C:\\Users\\dinam\\OneDrive\\Documents\\huji\\research\\detectors_noise\\LIGO (O3)\\org_public_0169_P2000251_001_O3-L1-C01_CLEAN_SUB60HZ-1240573680.0_sensitivity_strain_asd.txt"

get_detector_sensitivity("LIGO (O3)", strain_freq_file_path, delimiter='\t')
# Out:
# {'LIGO (O3)': {'freq_range': [35.25, 1764.25],
#   'min_strain': 3.8613662e-24,
#   'strain_threshold': 1.1584098599999998e-23}}

# %%
# Voyager
strain_freq_file_path = "C:\\Users\\dinam\\OneDrive\\Documents\\huji\\research\\detectors_noise\\curves_Jan_2020\\curves_Jan_2020\\voyager.txt"

get_detector_sensitivity("Voyager", strain_freq_file_path, delimiter='\t')
# Out:
# {'Voyager': {'freq_range': [25.511, 1204.8],
#   'min_strain': 8.3629e-25,
#   'strain_threshold': 2.50887e-24}}

# %%
# Voyager
strain_freq_file_path = "C:\\Users\\dinam\\OneDrive\\Documents\\huji\\research\\detectors_noise\\curves_Jan_2020\\curves_Jan_2020\\aplus.txt"

get_detector_sensitivity("LIGO A+", strain_freq_file_path, delimiter=' ')
# Out:
# {'LIGO A+': {'freq_range': [34.375506, 1814.7771],
#   'min_strain': 1.5367463e-24,
#   'strain_threshold': 4.6102389e-24}}
